# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Data.csv")
df.head(10)
# Out:
#        destination  passanger weather  temperature                 coupon  \
# 0  No Urgent Place      Alone   Sunny           55        Restaurant(<20)
# 1  No Urgent Place  Friend(s)   Sunny           80           Coffee House
# 2  No Urgent Place  Friend(s)   Sunny           80  Carry out & Take away
# 3  No Urgent Place  Friend(s)   Sunny           80           Coffee House
# 4  No Urgent Place  Friend(s)   Sunny           80           Coffee House
# 5  No Urgent Place  Friend(s)   Sunny           80        Restaurant(<20)
# 6  No Urgent Place  Friend(s)   Sunny           55  Carry out & Take away
# 7  No Urgent Place     Kid(s)   Sunny           80        Restaurant(<20)
# 8  No Urgent Place     Kid(s)   Sunny           80  Carry out & Take away
# 9  No Urgent Place     Kid(s)   Sunny           80                    Bar
#
#   expiration  gender age      maritalStatus  has_children  ... CoffeeHouse  \
# 0         1d  Female  21  Unmarried partner             1  ...       never
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   coupon                12684 non-null  object
#  5   expiration            12684 non-null  object
#  6   gender                12684 non-null  object
#  7   age                   12684 non-null  object
#  8   maritalStatus         12684 non-null  object
#  9   has_children          12684 non-null  int64
#  10  education             12684 non-null  object
#  11  occupation            12684 non-null  object
#  12  income                12684 non-null  object
#  13  car                   108 non-null    object
#  14  Bar                   12577 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Accept(Y/N?)                0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Accept(Y/N?)                0
# dtype: int64

# %%
df['destination'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12679    False
# 12680    False
# 12681    False
# 12682    False
# 12683    False
# Name: destination, Length: 12684, dtype: bool

# %%
df.isnull().sum()*100/len(df)
# Out:
# destination              0.000000
# passanger                0.000000
# weather                  0.000000
# temperature              0.000000
# coupon                   0.000000
# expiration               0.000000
# gender                   0.000000
# age                      0.000000
# maritalStatus            0.000000
# has_children             0.000000
# education                0.000000
# occupation               0.000000
# income                   0.000000
# car                     99.148534
# Bar                      0.843582
# CoffeeHouse              1.710817
# CarryAway                1.190476
# RestaurantLessThan20     1.024913
# Restaurant20To50         1.490066
# toCoupon_GEQ5min         0.000000
# toCoupon_GEQ15min        0.000000
# toCoupon_GEQ25min        0.000000
# direction_same           0.000000
# direction_opp            0.000000
# Accept(Y/N?)             0.000000
# dtype: float64

# %%
df['car'].value_counts()
# Out:
# Scooter and motorcycle                      22
# Mazda5                                      22
# do not drive                                22
# crossover                                   21
# Car that is too old to install Onstar :D    21
# Name: car, dtype: int64

# %%
# in above 1st approach - if we have very small missing value - 0.05% - we can drop that row
# in above 2nd approach - if we have very large missing value more than 50per-we can drop that column

# %%
df['Bar'].value_counts()
# Out:
# never    5197
# less1    3482
# 1~3      2473
# 4~8      1076
# gt8       349
# Name: Bar, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   coupon                12684 non-null  object
#  5   expiration            12684 non-null  object
#  6   gender                12684 non-null  object
#  7   age                   12684 non-null  object
#  8   maritalStatus         12684 non-null  object
#  9   has_children          12684 non-null  int64
#  10  education             12684 non-null  object
#  11  occupation            12684 non-null  object
#  12  income                12684 non-null  object
#  13  car                   108 non-null    object
#  14  Bar                   12577 non-null  object
# ...

# %%
#if type is object, it is categorical, so we have to apply mode - doing on column Bar
df['Bar']=df['Bar'].fillna(df['Bar'].mode()[0])

# %%
df['CoffeeHouse']=df['CoffeeHouse'].fillna(df['CoffeeHouse'].mode()[0])
df['RestaurantLessThan20']=df['RestaurantLessThan20'].fillna(df['RestaurantLessThan20'].mode()[0])
df['CarryAway']=df['CarryAway'].fillna(df['CarryAway'].mode()[0])
df['Restaurant20To50']=df['Restaurant20To50'].fillna(df['Restaurant20To50'].mode()[0])

# %%
#dropping 'car' column
df = df.drop(['car'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   coupon                12684 non-null  object
#  5   expiration            12684 non-null  object
#  6   gender                12684 non-null  object
#  7   age                   12684 non-null  object
#  8   maritalStatus         12684 non-null  object
#  9   has_children          12684 non-null  int64
#  10  education             12684 non-null  object
#  11  occupation            12684 non-null  object
#  12  income                12684 non-null  object
#  13  Bar                   12684 non-null  object
#  14  CoffeeHouse           12684 non-null  object
# ...

# %%
df.describe()
# Out:
#         temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# count  12684.000000  12684.000000           12684.0       12684.000000
# mean      63.301798      0.414144               1.0           0.561495
# std       19.154486      0.492593               0.0           0.496224
# min       30.000000      0.000000               1.0           0.000000
# 25%       55.000000      0.000000               1.0           0.000000
# 50%       80.000000      0.000000               1.0           1.000000
# 75%       80.000000      1.000000               1.0           1.000000
# max       80.000000      1.000000               1.0           1.000000
#
#        toCoupon_GEQ25min  direction_same  direction_opp  Accept(Y/N?)
# count       12684.000000    12684.000000   12684.000000  12684.000000
# mean            0.119126        0.214759       0.785241      0.568433
# std             0.323950        0.410671       0.410671      0.495314
# ...

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
iqr = Q3-Q1
upper_fence= Q3+1.5*iqr
lower_fence= Q1-1.5*iqr
print('upper fence \n', upper_fence)
print('lowe fence \n', lower_fence)
# Out:
# upper fence
#  temperature          117.5
# has_children           2.5
# toCoupon_GEQ5min       1.0
# toCoupon_GEQ15min      2.5
# toCoupon_GEQ25min      0.0
# direction_same         0.0
# direction_opp          1.0
# Accept(Y/N?)           2.5
# dtype: float64
# lowe fence
#  temperature          17.5
# has_children         -1.5
# toCoupon_GEQ5min      1.0
# toCoupon_GEQ15min    -1.5
# toCoupon_GEQ25min     0.0
# direction_same        0.0
# direction_opp         1.0
# Accept(Y/N?)         -1.5
# dtype: float64

# %%
# Creating boxplot for all numerical columns checking for outlier

def boxplot(cols):
    sns.boxplot(y=df[cols])
    plt.show()
    
for i in list(df.select_dtypes(exclude=['object']).columns):
    boxplot(i)

# %%
df_num =df.copy()
df_num=df_num.select_dtypes(exclude=['object'])
plt.figure(figsize=(16,4))
sns.boxplot(data=df_num)
# Out:
# <AxesSubplot:>

# %%
#no ouliers present in numerical columns

# %%
df.describe()
# Out:
#         temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# count  12684.000000  12684.000000           12684.0       12684.000000
# mean      63.301798      0.414144               1.0           0.561495
# std       19.154486      0.492593               0.0           0.496224
# min       30.000000      0.000000               1.0           0.000000
# 25%       55.000000      0.000000               1.0           0.000000
# 50%       80.000000      0.000000               1.0           1.000000
# 75%       80.000000      1.000000               1.0           1.000000
# max       80.000000      1.000000               1.0           1.000000
#
#        toCoupon_GEQ25min  direction_same  direction_opp  Accept(Y/N?)
# count       12684.000000    12684.000000   12684.000000  12684.000000
# mean            0.119126        0.214759       0.785241      0.568433
# std             0.323950        0.410671       0.410671      0.495314
# ...

# %%
df.isnull().sum()
# Out:
# destination             0
# passanger               0
# weather                 0
# temperature             0
# coupon                  0
# expiration              0
# gender                  0
# age                     0
# maritalStatus           0
# has_children            0
# education               0
# occupation              0
# income                  0
# Bar                     0
# CoffeeHouse             0
# CarryAway               0
# RestaurantLessThan20    0
# Restaurant20To50        0
# toCoupon_GEQ5min        0
# toCoupon_GEQ15min       0
# toCoupon_GEQ25min       0
# direction_same          0
# direction_opp           0
# Accept(Y/N?)            0
# dtype: int64

# %%
df.rename(columns={'Accept(Y/N?)':'Accept'}, inplace=True)

# %%
#DATA VISULAIZATION
#pie plot  -also to be plotted for categorical value
plt.figure(figsize=(5,5))
plt.pie(x=df['Accept'].value_counts(),labels=df['Accept'].value_counts().index, autopct="%0.2f%%", data=df)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbec38a4700>,
# ...
#  [Text(-0.2346688796802914, 1.0746769360647863, '1'),
#   Text(0.2346689802988064, -1.0746769140934957, '0')],
#  [Text(-0.12800120709834076, 0.5861874196717016, '56.84%'),
#   Text(0.1280012619811671, -0.5861874076873612, '43.16%')])

# %%
[i for i in df.columns if df[i].dtype==object]
#df.columns.
# Out:
# ['destination',
#  'passanger',
#  'weather',
#  'coupon',
#  'expiration',
#  'gender',
#  'age',
#  'maritalStatus',
#  'education',
#  'occupation',
#  'income',
#  'Bar',
#  'CoffeeHouse',
#  'CarryAway',
#  'RestaurantLessThan20',
#  'Restaurant20To50']

# %%
def univariate_analysis(col_list):
    fig, axs = plt.subplots(1,2,figsize=(10,3))
    for index, column_name in enumerate(col_list):
        df_temp = pd.DataFrame(sorted(list(df[column_name].unique())),columns=[column_name])
        df_temp['Total_Count'] = list(df.groupby(column_name).Accept.count())
        df_temp['Total_Count_per'] = list(df.groupby(column_name).Accept.count())
        df_temp['Accepted'] = list(df[df.Accept==1].groupby(column_name).Accept.count())
        df_temp['Rejected'] = list(df[df.Accept==0].groupby(column_name).Accept.count())
        df_temp['%Accepted'] = round(df_temp['Accepted']/df_temp['Total_Count']*100,3)
        df_temp['%Rejected'] = round(df_temp['Rejected']/df_temp['Total_Count']*100,3)
        df_temp = df_temp.sort_values(by='Total_Count', ascending=False)

        axs[index].barh(df_temp[column_name],df_temp['Total_Count'])
        axs[index].barh(df_temp[column_name],df_temp['Accepted'])
            # Add the percentage labels on top of the bars
        for i, v in enumerate(df_temp['%Accepted']):
            if v >0:
                axs[index].text(v + 1, i - 0.1, str(round(v)) + '%')

        axs[index].legend(labels=['Total','Accepted'])
        axs[index].set_xlabel('Counts')
        axs[index].set_title(column_name+' wise accepted coupons')
    plt.show()

# %%
col_list=['destination', 'weather']
univariate_analysis(col_list)

# %% [markdown]
# # observations
# 1. Majority of people go to 'No urgent place' and Coupon Acceptance percentage is more, i.e., 63%
# 2. Acceptance percentage of people who go to Home and Work is nearly 50%
# 3. People mostly go in 'sunny' weather and Coupon Acceptance % is more for the same, i.e., 63%
# 4. Only around 11% go in snowy and rainy weather

# %%
col_list=['passanger', 'maritalStatus']
univariate_analysis(col_list)

# %% [markdown]
# # observations
# 1. 60% of people go 'Alone' and 53% people accept coupons
# 2. Nearly 65% people accept coupons when travelling with 'Partner' and 'Friend'
# 3. People who are Single or with married partner travel often and have atleast 54% acceptance
# 4. Only approx 10% of people travel with 'Partner'/'kids' and only around 5% of people are widowed/divorced

# %%
col_list=['age', 'education']
univariate_analysis(col_list)

# %% [markdown]
# Count of people with age 21 &26 is high and their coupon acceptance ratio is also very high.
# Number of Students who are in some college/Bachelors degree is more and their acceptance ratio is also very high.

# %%
col_list=['occupation', 'income']
univariate_analysis(col_list)

# %%
col_list=['coupon', 'expiration']
univariate_analysis(col_list)

# %% [markdown]
# Lot of Coffee House coupons are offered, but their acceptance is just 50%.
# Restaurant(<20) & Carry Away have 70% acceptance ratio.
# 1d expiration coupons are accepted more compared to 2h

# %%
col_list=['RestaurantLessThan20', 'CoffeeHouse']
univariate_analysis(col_list)

# %%
col_list=['direction_same']
univariate_analysis(col_list)

# %%
#bivariate analysis
sns.countplot(x="passanger", hue="destination", data=df);

# %%
sns.catplot(x="passanger", hue="weather", col="destination", kind="count",data=df);

# %% [markdown]
# #observation
# Friends only go to 'no urgent place',

# %%
sns.catplot(x="passanger", hue="maritalStatus", col="destination", kind="count",data=df);

# %%
df_indep = df.drop(['Accept'], axis=1)
sns.heatmap(df_indep.corr(), annot=True)
plt.show()

# %%
#direction_opp and direction_same are inversely coorelated, and hence one can be dropped
df3=df.copy()
df_indep.drop('direction_opp', axis=1,inplace=True)
df_indep.columns
# Out:
# Index(['destination', 'passanger', 'weather', 'temperature', 'coupon',
#        'expiration', 'gender', 'age', 'maritalStatus', 'has_children',
#        'education', 'occupation', 'income', 'Bar', 'CoffeeHouse', 'CarryAway',
#        'RestaurantLessThan20', 'Restaurant20To50', 'toCoupon_GEQ5min',
#        'toCoupon_GEQ15min', 'toCoupon_GEQ25min', 'direction_same'],
#       dtype='object')

# %%
#toCoupon_GEQ5min column has zero variance, hence dropping it
df4= df.copy()
df_indep.drop('toCoupon_GEQ5min', axis=1, inplace=True)#can use inPlace=True also
df_indep.columns
# Out:
# Index(['destination', 'passanger', 'weather', 'temperature', 'coupon',
#        'expiration', 'gender', 'age', 'maritalStatus', 'has_children',
#        'education', 'occupation', 'income', 'Bar', 'CoffeeHouse', 'CarryAway',
#        'RestaurantLessThan20', 'Restaurant20To50', 'toCoupon_GEQ15min',
#        'toCoupon_GEQ25min', 'direction_same'],
#       dtype='object')

# %%
#feature Engineering, combining toCoupon_GEQ15min and toCoupon_GEQ25min into one
to_coupon = []
for i in range(df_indep.shape[0]):
    if (list(df_indep['toCoupon_GEQ15min'])[i] == 0):
        to_coupon.append(0)
    elif (list(df_indep['toCoupon_GEQ15min'])[i] == 1)and(list(df_indep['toCoupon_GEQ25min'])[i] == 0):
        to_coupon.append(1)
    else:
        to_coupon.append(2)
        
df_indep['to_coupon'] = to_coupon
df_indep['to_coupon'].describe()
# Out:
# count    12684.000000
# mean         0.680621
# std          0.675029
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          2.000000
# Name: to_coupon, dtype: float64

# %%
df_indep['coupon'].value_counts()
# Out:
# Coffee House             3996
# Restaurant(<20)          2786
# Carry out & Take away    2393
# Bar                      2017
# Restaurant(20-50)        1492
# Name: coupon, dtype: int64

# %%
# FE -- coupon_freq = RestaurantLessThan20, CoffeeHouse, CarryAway, Bar, Restaurant20To50
coupon_freq = []
for i in range(df_indep.shape[0]):
    if (list(df_indep['coupon'])[i] == 'Restaurant(<20)'):
        coupon_freq.append(list(df_indep['RestaurantLessThan20'])[i])
    elif (list(df_indep['coupon'])[i] == 'Coffee House'):
        coupon_freq.append(list(df_indep['CoffeeHouse'])[i])
    elif (list(df_indep['coupon'])[i] == 'Carry out & Take away'):
        coupon_freq.append(list(df_indep['CarryAway'])[i])
    elif (list(df_indep['coupon'])[i] == 'Bar'):
        coupon_freq.append(list(df_indep['Bar'])[i])
    elif (list(df_indep['coupon'])[i] == 'Restaurant(20-50)'):
        coupon_freq.append(list(df_indep['Restaurant20To50'])[i])
        
df_indep['coupon_freq'] = coupon_freq
df_indep['coupon_freq'].describe()
# Out:
# count     12684
# unique        5
# top         1~3
# freq       3892
# Name: coupon_freq, dtype: object

# %%
df['coupon_freq']=df_indep['coupon_freq']

# %%
sns.countplot(x="coupon_freq", hue="coupon", data=df);

# %% [markdown]
# #observations
# Coupons are distributed more to people who visited 1to 3 Restaurant(<20) and less1 of coffee house

# %%
#Acceptance of coupons based on  coupon_freq - multivariate analysis
sns.catplot(x="coupon_freq", hue="coupon", col="Accept", kind="count",data=df);

# %% [markdown]
# #observations
# Most users have visited more than one time((1~3 & 4~8) Restaurant(<20) and Carry Away services and also they have the highest coupon acceptance ratio.
# Rejection ratio is very high if Bar and Coffee House is given if they have never visited
# People visiting Bar and Restaurant(20-50) greater than 4 times is very less.

# %%
df_indep.columns
# Out:
# Index(['destination', 'passanger', 'weather', 'temperature', 'coupon',
#        'expiration', 'gender', 'age', 'maritalStatus', 'has_children',
#        'education', 'occupation', 'income', 'Bar', 'CoffeeHouse', 'CarryAway',
#        'RestaurantLessThan20', 'Restaurant20To50', 'toCoupon_GEQ15min',
#        'toCoupon_GEQ25min', 'direction_same', 'to_coupon', 'coupon_freq'],
#       dtype='object')

# %%
sns.heatmap(df_indep.corr(), annot=True)
plt.show()

# %%
#changing categorical columns
df.columns

[(i,len(df[i].value_counts())) for i in df.columns  if df[i].dtype==object]
#[df[i].value_counts() for i in df.columns  if df[i].dtype==object]
df5 = df.copy()

# %%
df.head()
# Out:
#        destination  passanger weather  temperature                 coupon  \
# 0  No Urgent Place      Alone   Sunny           55        Restaurant(<20)
# 1  No Urgent Place  Friend(s)   Sunny           80           Coffee House
# 2  No Urgent Place  Friend(s)   Sunny           80  Carry out & Take away
# 3  No Urgent Place  Friend(s)   Sunny           80           Coffee House
# 4  No Urgent Place  Friend(s)   Sunny           80           Coffee House
#
#   expiration  gender age      maritalStatus  has_children  ... CarryAway  \
# 0         1d  Female  21  Unmarried partner             1  ...       1~3
# 1         2h  Female  21  Unmarried partner             1  ...       1~3
# 2         2h  Female  21  Unmarried partner             1  ...       1~3
# 3         2h  Female  21  Unmarried partner             1  ...       1~3
# 4         1d  Female  21  Unmarried partner             1  ...       1~3
#
#   RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# ...

# %%
df['age'].value_counts()
# Out:
# 21         2653
# 26         2559
# 31         2039
# 50plus     1788
# 36         1319
# 41         1093
# 46          686
# below21     547
# Name: age, dtype: int64

# %%
df['education'].value_counts()
# Out:
# Some college - no degree                  4351
# Bachelors degree                          4335
# Graduate degree (Masters or Doctorate)    1852
# Associates degree                         1153
# High School Graduate                       905
# Some High School                            88
# Name: education, dtype: int64

# %%
df['income'].value_counts()
# Out:
# $25000 - $37499     2013
# $12500 - $24999     1831
# $37500 - $49999     1805
# $100000 or More     1736
# $50000 - $62499     1659
# Less than $12500    1042
# $87500 - $99999      895
# $75000 - $87499      857
# $62500 - $74999      846
# Name: income, dtype: int64

# %%
#normal label encoding for ordinal categories and colmn that has more categories
from sklearn import preprocessing
label = preprocessing.LabelEncoder()

# %%
df5['education'] = label.fit_transform(df5['education'])

# %%
df5['age'] = label.fit_transform(df5['age'])

# %%
df5['income'] = label.fit_transform(df5['income'])

# %%
df5['occupation'] = label.fit_transform(df5['occupation'])

# %%
#for others one hot encoding
cat_cols = [i for i in df.columns  if df5[i].dtype==object]
cat_cols
# Out:
# ['destination',
#  'passanger',
#  'weather',
#  'coupon',
#  'expiration',
#  'gender',
#  'maritalStatus',
#  'Bar',
#  'CoffeeHouse',
#  'CarryAway',
#  'RestaurantLessThan20',
#  'Restaurant20To50',
#  'coupon_freq']

# %%
df6=df5.copy()
df5= pd.get_dummies(df5, columns = cat_cols, drop_first=True)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 53 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   temperature                      12684 non-null  int64
#  1   age                              12684 non-null  int64
#  2   has_children                     12684 non-null  int64
#  3   education                        12684 non-null  int64
#  4   occupation                       12684 non-null  int64
#  5   income                           12684 non-null  int64
#  6   toCoupon_GEQ5min                 12684 non-null  int64
#  7   toCoupon_GEQ15min                12684 non-null  int64
#  8   toCoupon_GEQ25min                12684 non-null  int64
#  9   direction_same                   12684 non-null  int64
#  10  direction_opp                    12684 non-null  int64
#  11  Accept                           12684 non-null  int64
# ...

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     print (df5.head(5))

# %%
len([i for i in df5.columns if df5[i].dtype==object])
# Out:
# 0

# %%
df['occupation'].value_counts()
# Out:
# Unemployed                                   1870
# Student                                      1584
# Computer & Mathematical                      1408
# Sales & Related                              1093
# Education&Training&Library                    943
# Management                                    838
# Office & Administrative Support               639
# Arts Design Entertainment Sports & Media      629
# Business & Financial                          544
# Retired                                       495
# Food Preparation & Serving Related            298
# Healthcare Practitioners & Technical          244
# Healthcare Support                            242
# Community & Social Services                   241
# Legal                                         219
# Transportation & Material Moving              218
# Architecture & Engineering                    175
# Personal Care & Service                       175
# Protective Service                            175
# ...

# %%
df['education'].value_counts()
# Out:
# Some college - no degree                  4351
# Bachelors degree                          4335
# Graduate degree (Masters or Doctorate)    1852
# Associates degree                         1153
# High School Graduate                       905
# Some High School                            88
# Name: education, dtype: int64

# %%
df5.columns
# Out:
# Index(['temperature', 'age', 'has_children', 'education', 'occupation',
#        'income', 'toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
#        'direction_same', 'direction_opp', 'Accept',
#        'destination_No Urgent Place', 'destination_Work',
#        'passanger_Friend(s)', 'passanger_Kid(s)', 'passanger_Partner',
#        'weather_Snowy', 'weather_Sunny', 'coupon_Carry out & Take away',
#        'coupon_Coffee House', 'coupon_Restaurant(20-50)',
#        'coupon_Restaurant(<20)', 'expiration_2h', 'gender_Male',
#        'maritalStatus_Married partner', 'maritalStatus_Single',
#        'maritalStatus_Unmarried partner', 'maritalStatus_Widowed', 'Bar_4~8',
#        'Bar_gt8', 'Bar_less1', 'Bar_never', 'CoffeeHouse_4~8',
#        'CoffeeHouse_gt8', 'CoffeeHouse_less1', 'CoffeeHouse_never',
#        'CarryAway_4~8', 'CarryAway_gt8', 'CarryAway_less1', 'CarryAway_never',
#        'RestaurantLessThan20_4~8', 'RestaurantLessThan20_gt8',
# ...

# %%
x=df5.drop('Accept', axis=1).values #independent
y=df5['Accept'].values

# %%
y
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=17)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.transform(x_test)

# %%
df5['Accept'].value_counts()
# Out:
# 1    7210
# 0    5474
# Name: Accept, dtype: int64

# %%
def plot_auc(model_name, roc_param):
    plt.figure(1)
    lw = 2
    plt.plot(fpr_dt, tpr_dt, color='green',
             lw=lw, label=model_name+'(AUC = %0.2f)' % roc_param)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Area Under Curve')
    plt.legend(loc="lower right")
    plt.show()

# %%
import itertools
def plot_confusion_matrix(model, normalize=False): # This function prints and plots the confusion matrix.
    cm = confusion_matrix(y_test, model, labels=[0, 1])
    classes=[" Not Accepted", "Accepted"]
    cmap = plt.cm.Blues
    title = "Confusion Matrix"
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=3)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,accuracy_score, confusion_matrix

# %%
LR =LogisticRegression()
fit= LR.fit(x_train,y_train)
y_pred_train = LR.predict(x_train)
y_pred_test = LR.predict(x_test)

# %%
print(classification_report(y_test, y_pred_test))
print('**************************')
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.56      0.62      1115
#            1       0.70      0.80      0.75      1422
#
#     accuracy                           0.70      2537
#    macro avg       0.69      0.68      0.68      2537
# weighted avg       0.70      0.70      0.69      2537
#
# **************************
#               precision    recall  f1-score   support
#
#            0       0.71      0.59      0.64      4359
#            1       0.72      0.82      0.77      5788
#
#     accuracy                           0.72     10147
#    macro avg       0.72      0.70      0.70     10147
# weighted avg       0.72      0.72      0.71     10147

# %%
plt.figure(figsize=(6,6))
plot_confusion_matrix(y_pred_test, normalize=False)
plt.show()

# %%
from sklearn.metrics import auc, roc_curve
fpr_dt, tpr_dt, _ = roc_curve(y_test, y_pred_test)
roc_auc_dt = auc(fpr_dt, tpr_dt)
plot_auc('Logisitc Regression', roc_auc_dt)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=17, max_depth=10, criterion='gini')
dtfit = dt.fit(x_train,y_train)
y_pred_test_dt = dt.predict(x_test)
y_pred_train_dt = dt.predict(x_train)

# %%
print(classification_report(y_test, y_pred_test_dt))
print('**************************')
print(classification_report(y_train, y_pred_train_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.54      0.61      1115
#            1       0.69      0.81      0.75      1422
#
#     accuracy                           0.69      2537
#    macro avg       0.70      0.68      0.68      2537
# weighted avg       0.70      0.69      0.69      2537
#
# **************************
#               precision    recall  f1-score   support
#
#            0       0.81      0.65      0.72      4359
#            1       0.77      0.89      0.82      5788
#
#     accuracy                           0.79     10147
#    macro avg       0.79      0.77      0.77     10147
# weighted avg       0.79      0.79      0.78     10147

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=17, max_depth=10, criterion='entropy')
dtfit = dt.fit(x_train,y_train)
y_pred_test_dt2 = dt.predict(x_test)
y_pred_train_dt2 = dt.predict(x_train)

# %%
print(classification_report(y_test, y_pred_test_dt2))
print('**************************')
print(classification_report(y_train, y_pred_train_dt2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.56      0.61      1115
#            1       0.70      0.80      0.74      1422
#
#     accuracy                           0.69      2537
#    macro avg       0.69      0.68      0.68      2537
# weighted avg       0.69      0.69      0.69      2537
#
# **************************
#               precision    recall  f1-score   support
#
#            0       0.79      0.66      0.72      4359
#            1       0.77      0.87      0.82      5788
#
#     accuracy                           0.78     10147
#    macro avg       0.78      0.77      0.77     10147
# weighted avg       0.78      0.78      0.78     10147

# %%
plt.figure(figsize=(6,6))
plot_confusion_matrix(y_pred_test_dt2, normalize=False)
plt.show()

# %%
accuracy_score(y_test, y_pred_test_dt2)
# Out:
# 0.6913677571935357

# %%
from sklearn.metrics import auc, roc_curve
fpr_dt, tpr_dt, _ = roc_curve(y_test, y_pred_test_dt2)
roc_auc_dt = auc(fpr_dt, tpr_dt)
plot_auc('Decision tree', roc_auc_dt)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# from sklearn.model_selection import GridSearchCV
# param_grid={'max_depth':[5,10,15,20,25],'criterion':['gini','entropy'],
#            'min_samples_split':[1,5,7,10], 'n_estimators':[5,10,15,20,25]}
# rf1=RandomForestClassifier()
# grid=GridSearchCV(rf1,param_grid,cv=10)
# grid.fit(x_train,y_train)
# grid.best_params_

# %%
classifier4=RandomForestClassifier(criterion='gini', random_state=7,
                                  n_estimators=25,max_depth=25,min_samples_split=5)
rf=classifier4.fit(x_train,y_train)
y_pred_test_rf=classifier4.predict(x_test)
y_pred_train_rf=classifier4.predict(x_train)

# %%
print(classification_report(y_test, y_pred_test_rf))
print('**************************')
print(classification_report(y_train, y_pred_train_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.64      0.69      1115
#            1       0.74      0.82      0.78      1422
#
#     accuracy                           0.74      2537
#    macro avg       0.74      0.73      0.73      2537
# weighted avg       0.74      0.74      0.74      2537
#
# **************************
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      4359
#            1       0.94      0.97      0.96      5788
#
#     accuracy                           0.95     10147
#    macro avg       0.95      0.95      0.95     10147
# weighted avg       0.95      0.95      0.95     10147

# %%
classifier4=RandomForestClassifier(criterion='entropy', random_state=7,
                                  n_estimators=17,max_depth=15,min_samples_split=5)
rf=classifier4.fit(x_train,y_train)
y_pred_test_rf_entropy=classifier4.predict(x_test)
y_pred_train_rf_entropy=classifier4.predict(x_train)

# %%
print(classification_report(y_test, y_pred_test_rf_entropy))
print('**************************')
print(classification_report(y_train, y_pred_train_rf_entropy))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.61      0.67      1115
#            1       0.73      0.85      0.79      1422
#
#     accuracy                           0.74      2537
#    macro avg       0.74      0.73      0.73      2537
# weighted avg       0.74      0.74      0.74      2537
#
# **************************
#               precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88      4359
#            1       0.88      0.95      0.92      5788
#
#     accuracy                           0.90     10147
#    macro avg       0.91      0.89      0.90     10147
# weighted avg       0.90      0.90      0.90     10147

# %%
#Both Random Forest Gini and Entropy are going into overfitting stage, Hyper param tuning can be done to overcome this

# %%
from sklearn.ensemble import AdaBoostClassifier
abdc=AdaBoostClassifier(random_state=7)
abdc1=abdc.fit(x_train,y_train)
y_pred_test_abdc=abdc.predict(x_test)
y_pred_train_abdc=abdc.predict(x_train)
print(classification_report(y_test,y_pred_test_abdc))
print('***********')
print(classification_report(y_train,y_pred_train_abdc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.56      0.62      1115
#            1       0.70      0.81      0.75      1422
#
#     accuracy                           0.70      2537
#    macro avg       0.70      0.68      0.68      2537
# weighted avg       0.70      0.70      0.69      2537
#
# ***********
#               precision    recall  f1-score   support
#
#            0       0.71      0.59      0.64      4359
#            1       0.73      0.82      0.77      5788
#
#     accuracy                           0.72     10147
#    macro avg       0.72      0.70      0.71     10147
# weighted avg       0.72      0.72      0.72     10147

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
NB=nb.fit(x_train,y_train)
y_pred_test_nb=nb.predict(x_test)
y_pred_train_nb=nb.predict(x_train)
print(classification_report(y_test,y_pred_test_nb))
print('***********')
print(classification_report(y_train,y_pred_train_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.62      0.62      1115
#            1       0.70      0.70      0.70      1422
#
#     accuracy                           0.66      2537
#    macro avg       0.66      0.66      0.66      2537
# weighted avg       0.66      0.66      0.66      2537
#
# ***********
#               precision    recall  f1-score   support
#
#            0       0.63      0.62      0.63      4359
#            1       0.72      0.72      0.72      5788
#
#     accuracy                           0.68     10147
#    macro avg       0.67      0.67      0.67     10147
# weighted avg       0.68      0.68      0.68     10147

# %%
from xgboost import XGBClassifier
model=XGBClassifier(random_state=7,n_estimators=50)
xgb=model.fit(x_train,y_train)
y_pred_test_xgb=xgb.predict(x_test)
y_pred_train_xgb=xgb.predict(x_train)
print(classification_report(y_test,y_pred_test_xgb))
print('***********')
print(classification_report(y_train,y_pred_train_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.65      0.70      1115
#            1       0.75      0.83      0.79      1422
#
#     accuracy                           0.75      2537
#    macro avg       0.76      0.74      0.75      2537
# weighted avg       0.75      0.75      0.75      2537
#
# ***********
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84      4359
#            1       0.86      0.91      0.89      5788
#
#     accuracy                           0.87     10147
#    macro avg       0.87      0.86      0.86     10147
# weighted avg       0.87      0.87      0.86     10147

# %%
plt.figure(figsize=(6,6))
plot_confusion_matrix(y_pred_test_xgb, normalize=False)
plt.show()

# %%
from sklearn.metrics import auc, roc_curve
fpr_dt, tpr_dt, _ = roc_curve(y_test, y_pred_test_xgb)
roc_auc_dt = auc(fpr_dt, tpr_dt)
plot_auc('XG Boost', roc_auc_dt)

# %%
# from sklearn.model_selection import GridSearchCV
# tuned_param={'C':[0.01,0.05,0.1,0.2,0.3,0.5,0.7,1],'gamma':[0.01,0.1,0.05,0.5,1,5,10,20],
#             'kernel':['rbf','linear','poly']}
# svc=SVC(random_state=17)
# grid=GridSearchCV(svc,tuned_param,cv=10)
# grid.fit(x_train, y_train)
# grid.best_params_

# %%
from sklearn.svm import SVC
svc=SVC(random_state=7,C=.2, gamma=0.02)
SVM=svc.fit(x_train,y_train)
y_pred_test_svc=svc.predict(x_test)
y_pred_train_svc=svc.predict(x_train)

# %%
print(classification_report(y_test, y_pred_test_svc))
print('**************************')
print(classification_report(y_train, y_pred_train_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.53      0.62      1115
#            1       0.70      0.86      0.77      1422
#
#     accuracy                           0.71      2537
#    macro avg       0.72      0.69      0.70      2537
# weighted avg       0.72      0.71      0.70      2537
#
# **************************
#               precision    recall  f1-score   support
#
#            0       0.77      0.57      0.66      4359
#            1       0.73      0.87      0.79      5788
#
#     accuracy                           0.74     10147
#    macro avg       0.75      0.72      0.73     10147
# weighted avg       0.75      0.74      0.74     10147

# %%
plt.figure(figsize=(6,6))
plot_confusion_matrix(y_pred_test_svc, normalize=False)
plt.show()

# %%
from sklearn.metrics import auc, roc_curve
fpr_dt, tpr_dt, _ = roc_curve(y_test, y_pred_test_svc)
roc_auc_dt = auc(fpr_dt, tpr_dt)
plot_auc('SVC', roc_auc_dt)

# %%
list_met = []
list_accuracy = []

# Model 1
# Logistic Regression
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(C=0.4, max_iter=1000, solver='liblinear')
lr = classifier.fit(x_train, y_train)
# Prediction
y_pred = classifier.predict(x_test)
# Accuarcy
accuracy_LR = accuracy_score(y_test, y_pred)

# Model 2
from sklearn.tree import DecisionTreeClassifier
classifier2 = DecisionTreeClassifier(random_state=14)
dt = classifier2.fit(x_train, y_train)
# prediction
y_pred2 = classifier2.predict(x_test)
# evaluation
accuracy_DT = accuracy_score(y_test, y_pred2)

# Model 3
# criteria - gini
from sklearn.ensemble import RandomForestClassifier
classifier3 = RandomForestClassifier(criterion='gini', random_state=14,
                                  n_estimators=25,max_depth=25,min_samples_split=5)
rfi = classifier3.fit(x_train, y_train)
#prediction
y_pred3 = classifier3.predict(x_test)
# evaluation
accuracy_RFI = accuracy_score(y_test, y_pred3)

# Model 4
classifier4 = RandomForestClassifier(criterion='entropy', random_state=14,
                                  n_estimators=25,max_depth=25,min_samples_split=5)
rfe = classifier4.fit(x_train, y_train)
# predict
y_pred4 = classifier4.predict(x_test)
# evaluation
accuracy_RFE = accuracy_score(y_test, y_pred4)

# Model 5
from sklearn.svm import SVC

model_svm = SVC()
SVM = model_svm.fit(x_train, y_train)
#prediction
y_pred5 = model_svm.predict(x_test)
# evaluation
accuracy_SVC = accuracy_score(y_test, y_pred5)

# Model 6
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier()
knn = model_knn.fit(x_train, y_train)
#prediction
pred_knn = model_knn.predict(x_test)
# evaluation
accuracy_knn = accuracy_score(y_test, pred_knn)

# model 7
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb = gnb.fit(x_train, y_train)
# prediction
pred_gnb = gnb.predict(x_test)
# evaluation
accuracy_GNB = accuracy_score(y_test, pred_gnb)

# model 8
from sklearn.naive_bayes import BernoulliNB
model = BernoulliNB()
bnb = model.fit(x_train, y_train)
# prediction
pred_bnb = bnb.predict(x_test)
# evaluation
accuracy_BNB = accuracy_score(y_test, pred_bnb)

#model 9
from xgboost import XGBClassifier
xgb=XGBClassifier(random_state=14,n_estimators=50)
xgb=xgb.fit(x_train,y_train)
predict_xgb=xgb.predict(x_test)
# evaluation
accuracy_XGB = accuracy_score(y_test, predict_xgb)

# combining all the above model by using voting classifier model

from sklearn.ensemble import VotingClassifier

evc = VotingClassifier(estimators = [('lr', lr), ('DT', dt), ('RFI', rfi),('RFE', rfe),
                                     ('SVC', SVM), ('KNN', knn),('GNB', gnb),
                                    ('BNB', bnb),('XGB', xgb)], voting = 'hard',
                                    flatten_transform=True)

model_evc = evc.fit(x_train, y_train)
# prediction
pred_evc = evc.predict(x_test)
# evaluation
accuracy_evc = accuracy_score(y_test, pred_evc)

list1 = ["Logistic Regression",'Decision Tree','RandomForest Gini', 'RandomForest Entropy',
        'Support Vector','K Nearest Neighbors','GuassionNB','BernoulliNB','xg boost','Voting Classifier_hard']

list2 = [accuracy_LR,accuracy_DT,accuracy_RFI,accuracy_RFE,accuracy_SVC,accuracy_knn,
        accuracy_GNB,accuracy_BNB, accuracy_XGB, accuracy_evc]

list3 = [classifier,classifier2,classifier3,classifier4,model_svm,model_knn,
        gnb,model,xgb,model_evc]

df_accuracy = pd.DataFrame({'Method Used' :list1, "Accuracy" :list2})
print(df_accuracy)

charts = sns.barplot(x='Method Used', y = 'Accuracy', data=df_accuracy)
charts.set_xticklabels(charts.get_xticklabels(), rotation=90)
print(charts)
# Out:
#               Method Used  Accuracy
# 0     Logistic Regression  0.696098
# 1           Decision Tree  0.690579
# 2       RandomForest Gini  0.743792
# 3    RandomForest Entropy  0.743398
# 4          Support Vector  0.737485
# 5     K Nearest Neighbors  0.703587
# 6              GuassionNB  0.664564
# 7             BernoulliNB  0.683484
# 8                xg boost  0.754829
# 9  Voting Classifier_hard  0.739456
# AxesSubplot(0.125,0.11;0.775x0.77)
