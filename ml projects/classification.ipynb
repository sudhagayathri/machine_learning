# %%
# Students' Academic Performance Dataset (xAPI-Edu-Data)
# Data Set Characteristics: Multivariate

# Number of Instances: 480

# Area: E-learning, Education, Predictive models, Educational Data Mining

# Attribute Characteristics: Integer/Categorical

# Number of Attributes: 16

# Date: 2016-11-8

# Associated Tasks: Classification

# Missing Values? No

# File formats: xAPI-Edu-Data.csv

# Source:
# Elaf Abu Amrieh, Thair Hamtini, and Ibrahim Aljarah, The University of Jordan, Amman, Jordan, http://www.Ibrahimaljarah.com
# www.ju.edu.jo

# %%
# The dataset consists of 305 males and 175 females. The students come from different origins such as 179 students are from Kuwait, 172 students are from Jordan, 28 students from Palestine, 22 students are from Iraq, 17 students from Lebanon, 12 students from Tunis, 11 students from Saudi Arabia, 9 students from Egypt, 7 students from Syria, 6 students from USA, Iran and Libya, 4 students from Morocco and one student from Venezuela.

# The dataset is collected through two educational semesters: 245 student records are collected during the first semester and 235 student records are collected during the second semester.

# The data set includes also the school attendance feature such as the students are classified into two categories based on their absence days: 191 students exceed 7 absence days and 289 students their absence days under 7.

# This dataset includes also a new category of features; this feature is parent parturition in the educational process. Parent participation feature have two sub features: Parent Answering Survey and Parent School Satisfaction. There are 270 of the parents answered survey and 210 are not, 292 of the parents are satisfied from the school and 188 are not.

# (See the related papers for more details).

# Attributes
# 1 Gender - student's gender (nominal: 'Male' or 'Female’)

# 2 Nationality- student's nationality (nominal:’ Kuwait’,’ Lebanon’,’ Egypt’,’ SaudiArabia’,’ USA’,’ Jordan’,’
# Venezuela’,’ Iran’,’ Tunis’,’ Morocco’,’ Syria’,’ Palestine’,’ Iraq’,’ Lybia’)

# 3 Place of birth- student's Place of birth (nominal:’ Kuwait’,’ Lebanon’,’ Egypt’,’ SaudiArabia’,’ USA’,’ Jordan’,’
# Venezuela’,’ Iran’,’ Tunis’,’ Morocco’,’ Syria’,’ Palestine’,’ Iraq’,’ Lybia’)

# 4 Educational Stages- educational level student belongs (nominal: ‘lowerlevel’,’MiddleSchool’,’HighSchool’)

# 5 Grade Levels- grade student belongs (nominal: ‘G-01’, ‘G-02’, ‘G-03’, ‘G-04’, ‘G-05’, ‘G-06’, ‘G-07’, ‘G-08’, ‘G-09’, ‘G-10’, ‘G-11’, ‘G-12 ‘)

# 6 Section ID- classroom student belongs (nominal:’A’,’B’,’C’)

# 7 Topic- course topic (nominal:’ English’,’ Spanish’, ‘French’,’ Arabic’,’ IT’,’ Math’,’ Chemistry’, ‘Biology’, ‘Science’,’ History’,’ Quran’,’ Geology’)

# 8 Semester- school year semester (nominal:’ First’,’ Second’)
# 9 Parent responsible for student (nominal:’mom’,’father’)

# 10 Raised hand- how many times the student raises his/her hand on classroom (numeric:0-100)
# 11- Visited resources- how many times the student visits a course content(numeric:0-100)

# 12 Viewing announcements-how many times the student checks the new announcements(numeric:0-100)

# 13 Discussion groups- how many times the student participate on discussion groups (numeric:0-100)

# 14 Parent Answering Survey- parent answered the surveys which are provided from school or not
# (nominal:’Yes’,’No’)

# 15 Parent School Satisfaction- the Degree of parent satisfaction from school(nominal:’Yes’,’No’)

# 16 Student Absence Days-the number of absence days for each student (nominal: above-7, under-7)

# The students are classified into three numerical intervals based on their total grade/mark:
# Low-Level: interval includes values from 0 to 69,

# Middle-Level: interval includes values from 70 to 89,

# High-Level: interval includes values from 90-100.

# https://www.kaggle.com/search?q=engineering+datasetSize%3Asmall

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('xAPI-Edu-Data.csv')

# %%
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
#here we have 4 interger, rest object

# %%
df.shape
# Out:
# (480, 17)

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(y=df['raisedhands'])
# Out:
# <AxesSubplot:ylabel='raisedhands'>

# %%
sns.boxplot(y=df['VisITedResources'])
# Out:
# <AxesSubplot:ylabel='VisITedResources'>

# %%
#BOX plot is done only on numerical data, and no outliers found in numerical features

# %%
df['gender'].value_counts(dropna=False) #dropna =false says includes missing values
# Out:
# M    305
# F    175
# Name: gender, dtype: int64

# %%
df.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
df['Class'].value_counts(dropna=False)
# Out:
# M    211
# H    142
# L    127
# Name: Class, dtype: int64

# %%
df['Class'].value_counts(normalize=True)
# Out:
# M    0.439583
# H    0.295833
# L    0.264583
# Name: Class, dtype: float64

# %%
sns.countplot(df['Class'])
plt.plot()
# Out:
# []

# %%
#to see how many columns are object
a = df.select_dtypes(include=object).columns
print(a)
print(len(a))
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'ParentAnsweringSurvey',
#        'ParentschoolSatisfaction', 'StudentAbsenceDays', 'Class'],
#       dtype='object')
# 13

# %%
df.select_dtypes(exclude=object).columns
# Out:
# Index(['raisedhands', 'VisITedResources', 'AnnouncementsView', 'Discussion'], dtype='object')

# %%
plt.figure(figsize=(15,15))
plt.subplots_adjust(hspace=0.5)

for i in range(len(a)):
    plt.subplot(3, 5, i+1)
    plt.xticks(rotation=90)
    sns.countplot(df[a[i]])

# %%
sns.countplot("gender",data=df, hue="Class")
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
df.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
x=df.groupby(by='Class').agg(raisedhand=('raisedhands', 'mean'),
                           resources=('VisITedResources', 'mean'),
                           discussion=('Discussion', 'mean'),
                           annoucemnet =('AnnouncementsView', 'mean'))
print(x)
# Out:
#        raisedhand  resources  discussion  annoucemnet
# Class
# H       70.288732  78.746479   53.661972    53.380282
# L       16.889764  18.322835   30.834646    15.574803
# M       48.938389  60.635071   43.791469    40.962085

# %%
x.columns
# Out:
# Index(['raisedhand', 'resources', 'discussion', 'annoucemnet'], dtype='object')

# %%
x.index
# Out:
# Index(['H', 'L', 'M'], dtype='object', name='Class')

# %%
plt.pie(labels=x.index, x=x['raisedhand'].values, autopct='%0.2f')
plt.title('class and avg raisedhands')
# Out:
# Text(0.5, 1.0, 'class and avg raisedhands')

# %%
plt.pie(labels=x.index, x=x['discussion'].values, autopct='%0.2f')
plt.title('class and avg discussion')
# Out:
# Text(0.5, 1.0, 'class and avg discussion')

# %%
#here we can see that for both raisedhands, discussion they are directly proportional to class, the more their 
#average the more is their class

# %%
#MULTI VARIANT ANALYSIS

# %%
plt.figure(figsize=(7,7))
sns.swarmplot(x=df['Class'],y=df['Discussion'], hue=df['StudentAbsenceDays'])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Discussion'>

# %%
#here we can interpret that people who are StudentAbsenceDays > 7, are majority in low class, and in low class more 
#no of students are there who has participated lower in discussions

# %%
plt.figure(figsize=(7,7))
sns.swarmplot(x=df['Class'],y=df['VisITedResources'], hue=df['ParentAnsweringSurvey'])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='VisITedResources'>

# %%
#here VisITedResources are more for high class, 
#ParentAnsweringSurvey-no are more for low class

# %%
#here

# %%
c=len(df[(df['Topic']=='IT')])
a=len(df[(df['Topic']=='IT') & (df['Class'] == 'H')])
b=len(df[(df['Topic']=='IT') & (df['Class'] == 'M')])

# %%
print(((a+b)/c)*100)
# Out:
# 60.0

# %%
d=[]
e=[]
for i in df['Topic'].value_counts().index:
    c=len(df[(df['Topic']==i)])
    a=len(df[(df['Topic']==i) & (df['Class'] == 'H')])
    b=len(df[(df['Topic']==i) & (df['Class'] == 'M')])
    e.append(a+b/c*100)
    d.append(i)
    print(f'the percentage of students in {i} between 70 to 100 is {a+b/c *100 }')
    
print(e)
print(d)
sns.barplot(x=d,y=e)
plt.xticks(rotation=90)
plt.show()
# Out:
# the percentage of students in IT between 70 to 100 is 59.21052631578947
# the percentage of students in French between 70 to 100 is 64.61538461538461
# the percentage of students in Arabic between 70 to 100 is 57.983050847457626
# the percentage of students in Science between 70 to 100 is 65.01960784313725
# the percentage of students in English between 70 to 100 is 57.0
# the percentage of students in Biology between 70 to 100 is 49.33333333333333
# the percentage of students in Spanish between 70 to 100 is 53.0
# the percentage of students in Chemistry between 70 to 100 is 35.0
# the percentage of students in Geology between 70 to 100 is 81.0
# the percentage of students in Quran between 70 to 100 is 44.36363636363637
# the percentage of students in Math between 70 to 100 is 44.095238095238095
# the percentage of students in History between 70 to 100 is 67.15789473684211
# ...

# %%
d=[]
e=[]
for i in df['Topic'].value_counts().index:
    c=len(df[(df['Topic']==i)])
    a=len(df[(df['Topic']==i) & (df['Class'] == 'L')])
    e.append(a/c*100)
    d.append(i)
    print(f'the percentage of students in {i} between 0 to 70 is {a/c *100 }')
    
sns.barplot(x=d,y=e)
plt.xticks(rotation=90)
plt.show()
print(e)
print(d)
# Out:
# the percentage of students in IT between 0 to 70 is 40.0
# the percentage of students in French between 0 to 70 is 24.615384615384617
# the percentage of students in Arabic between 0 to 70 is 28.8135593220339
# the percentage of students in Science between 0 to 70 is 19.607843137254903
# the percentage of students in English between 0 to 70 is 22.22222222222222
# the percentage of students in Biology between 0 to 70 is 13.333333333333334
# the percentage of students in Spanish between 0 to 70 is 32.0
# the percentage of students in Chemistry between 0 to 70 is 33.33333333333333
# the percentage of students in Geology between 0 to 70 is 0.0
# the percentage of students in Quran between 0 to 70 is 27.27272727272727
# the percentage of students in Math between 0 to 70 is 33.33333333333333
# the percentage of students in History between 0 to 70 is 15.789473684210526
# ...

# %%
df.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
c=len(df[(df['ParentschoolSatisfaction']=='Good')])
a=len(df[(df['ParentschoolSatisfaction']=='Good') & (df['Class'] == 'H')])
print(a,c)
# Out:
# 118 292

# %%
df['StudentAbsenceDays'].value_counts()
# Out:
# Under-7    289
# Above-7    191
# Name: StudentAbsenceDays, dtype: int64

# %%
#FOR HIGH CLASS
d=[]
e=[]
for i in df['StudentAbsenceDays'].value_counts().index:
    a=len(df[(df['StudentAbsenceDays']==i) & (df['Class'] == 'H')])
    c=len(df[(df['StudentAbsenceDays']==i)])
    d.append(i)
    e.append(a/c*100)

print(d)
print(e)
sns.barplot(x=d, y =e)
plt.xticks(rotation=90)
# Out:
# ['Under-7', 'Above-7']
# [47.75086505190311, 2.094240837696335]
# (array([0, 1]), [Text(0, 0, 'Under-7'), Text(1, 0, 'Above-7')])

# %%
#FOR LOW CLASS
d=[]
e=[]
for i in df['StudentAbsenceDays'].value_counts().index:
    a=len(df[(df['StudentAbsenceDays']==i) & (df['Class'] == 'L')])
    c=len(df[(df['StudentAbsenceDays']==i)])
    d.append(i)
    e.append(a/c*100)

print(d)
print(e)
sns.barplot(x=d, y =e)
plt.xticks(rotation=90)
# Out:
# ['Under-7', 'Above-7']
# [3.8062283737024223, 60.73298429319372]
# (array([0, 1]), [Text(0, 0, 'Under-7'), Text(1, 0, 'Above-7')])

# %% [markdown]
# # model building starts

# %%
df1=df.copy()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
df.head(15)
# Out:
#    gender NationalITy PlaceofBirth       StageID GradeID SectionID Topic  \
# 0       M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 1       M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 2       M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 3       M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 4       M          KW       KuwaIT    lowerlevel    G-04         A    IT
# 5       F          KW       KuwaIT    lowerlevel    G-04         A    IT
# 6       M          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 7       M          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 8       F          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 9       F          KW       KuwaIT  MiddleSchool    G-07         B    IT
# 10      M          KW       KuwaIT  MiddleSchool    G-07         A  Math
# 11      M          KW       KuwaIT  MiddleSchool    G-07         B  Math
# ...

# %%
df1.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
df1.drop(columns=['NationalITy','SectionID', 'PlaceofBirth'],axis=1, inplace=True)

# %%
df1.head()
# Out:
#   gender     StageID GradeID Topic Semester Relation  raisedhands  \
# 0      M  lowerlevel    G-04    IT        F   Father           15
# 1      M  lowerlevel    G-04    IT        F   Father           20
# 2      M  lowerlevel    G-04    IT        F   Father           10
# 3      M  lowerlevel    G-04    IT        F   Father           30
# 4      M  lowerlevel    G-04    IT        F   Father           40
#
#    VisITedResources  AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                16                  2          20                   Yes
# 1                20                  3          25                   Yes
# 2                 7                  0          30                    No
# 3                25                  5          35                    No
# 4                50                 12          50                    No
#
#   ParentschoolSatisfaction StudentAbsenceDays Class
# 0                     Good            Under-7     M
# ...

# %%
sns.heatmap(df1.corr(), annot=True)
plt.show()

# %%
#label encoding

#cols = [i for i in df1.columns if df1[i].dtype == 'object']
cols = [(i, len(df1[i].value_counts())) for i in df1.columns if df1[i].dtype == 'object']
# cols.pop(-1) #removing class that is target varaible
cols
# Out:
# [('gender', 2),
#  ('StageID', 3),
#  ('GradeID', 10),
#  ('Topic', 12),
#  ('Semester', 2),
#  ('Relation', 2),
#  ('ParentAnsweringSurvey', 2),
#  ('ParentschoolSatisfaction', 2),
#  ('StudentAbsenceDays', 2),
#  ('Class', 3)]

# %%
df1= pd.get_dummies(df1, columns = cols, drop_first=True)

# %%
df1.head(3)

# %%
df1['Class'] = df1['Class'].replace({'L':0,'M':1, 'H':2})
df1.head(3)

# %%
x=df1.drop('Class', axis=1).values
x #independent varaibles
x

# %%
y = df1['Class'].values

# %%
y

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=17)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
clasfier= LogisticRegression()
lr = clasfier.fit(x_train, y_train)
y_pred= clasfier.predict(x_test)
y_pred_train = clasfier.predict(x_train)

# %%
print(classification_report(x_train,y_train))

# %%
from sklearn.tree import DecisionTreeClassifier
clasfier2 = DecisionTreeClassifier(random_state=7, max_depth=5, max_leaf_nodes=7, criterion='gini')
dt=clasfier2.fit(x_train, y_train)
y_pred2= clasfier2.predict(x_test)
y_pred_train2 = clasfier2.predict(x_train)

# %%
print(classification_report(y_test, y_pred2))
print('*********************')
print(classification_report(y_train, y_pred_train2))

# %%
accuracy_score( y_test, y_pred2)

# %%
from sklearn.model_selection import RandomizedSearchCV
param_grid = {'max_depth':[2,30], 'criterion': ['gini','entropy'],
            'max_leaf_nodes' : [2,20], 'min_samples_split' :[10,40]}
dt1 = DecisionTreeClassifier(random_state=7)            
grid =RandomizedSearchCV(dt1, param_grid, cv=10)
grid.fit(x_train, y_train)
grid.best_params_

# %%
from sklearn.tree import DecisionTreeClassifier
clasfier2 = DecisionTreeClassifier(random_state=7, max_depth=30, max_leaf_nodes=20, criterion='gini',min_samples_split=10)
dt=clasfier2.fit(x_train, y_train)
y_pred3= clasfier2.predict(x_test)
y_pred_train3 = clasfier2.predict(x_train)

# %%
print(classification_report(y_test, y_pred3))
print('*********************')
print(classification_report(y_train, y_pred_train3))

# %%
#here we see in randomisied search cv, it chooses random values, but we can see its underoging
#overfitting issue as accuracy for test is 71, but for training it is 84


#diff btn randomised serach and gridsearchcsv:

#gridsearchcsv - can be used when dataset is small as it takes little time
#randomisedsearch - it chooses randomly and can be  used for large data

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'max_depth':[2,5,7,10,15,20,25,30],'criterion':['gini','entropy'],
           'max_leaf_nodes':[2,5,10,15,20,25],'min_samples_split':[10,15,20,25,30,35,40]}
dt1=DecisionTreeClassifier(random_state=7)
grid=GridSearchCV(dt1,param_grid,cv=10)
grid.fit(x_train,y_train)
grid.best_params_

# %%
from sklearn.tree import DecisionTreeClassifier
clasfier2 = DecisionTreeClassifier(random_state=7, max_depth=7, max_leaf_nodes=10, criterion='gini',min_samples_split=10)
dt=clasfier2.fit(x_train, y_train)
y_pred4= clasfier2.predict(x_test)
y_pred_train4 = clasfier2.predict(x_train)

# %%
print(classification_report(y_test, y_pred4))
print('*********************')
print(classification_report(y_train, y_pred_train4))

# %%
#stil we see overfitting (72, 81)

# %%
from sklearn.ensemble import RandomForestClassifier
clasfier4 = RandomForestClassifier(criterion='gini', random_state=17, n_estimators =7, max_depth=10, max_leaf_nodes=25, oob_score=True)
rf=clasfier4.fit(x_train, y_train)
y_pred5= clasfier4.predict(x_test)
y_pred_train5 = clasfier4.predict(x_train)

# %%
print(classification_report(y_test, y_pred5))
print('*********************')
print(classification_report(y_train, y_pred_train5))

# %%
#now we see accuracy is better , amd no overfitting

# %%
from sklearn.svm import SVC
svc = SVC(random_state=7)
SVM = svc.fit(x_train, y_train)
y_pred6= SVM.predict(x_test)
y_pred_train6 = SVM.predict(x_train)

# %%
print(classification_report(y_test, y_pred6))
print('*********************')
print(classification_report(y_train, y_pred_train6))

# %%
#accuracy is 73,85
